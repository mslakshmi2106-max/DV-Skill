# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("/content/sample_data/samplesuperstore.xlsx")

# %%
df.head()
# Out:
#    Row ID        Order ID           Order Date            Ship Date  \
# 0       1  US-2023-103800  2023-03-01 00:00:00  2023-07-01 00:00:00
# 1       2  US-2023-112326  2023-04-01 00:00:00  2023-08-01 00:00:00
# 2       3  US-2023-112326  2023-04-01 00:00:00  2023-08-01 00:00:00
# 3       4  US-2023-112326  2023-04-01 00:00:00  2023-08-01 00:00:00
# 4       5  US-2023-141817  2023-05-01 00:00:00  2023-12-01 00:00:00
#
#         Ship Mode Customer ID  Customer Name      Segment Country/Region  \
# 0  Standard Class    DP-13000  Darren Powers     Consumer  United States
# 1  Standard Class    PO-19195  Phillina Ober  Home Office  United States
# 2  Standard Class    PO-19195  Phillina Ober  Home Office  United States
# 3  Standard Class    PO-19195  Phillina Ober  Home Office  United States
# 4  Standard Class    MB-18085     Mick Brown     Consumer  United States
#
#            City  ... Postal Code   Region       Product ID         Category  \
# 0       Houston  ...       77095  Central  OFF-PA-10000174  Office Supplies
# 1    Naperville  ...       60540  Central  OFF-BI-10004094  Office Supplies
# 2    Naperville  ...       60540  Central  OFF-LA-10003223  Office Supplies
# 3    Naperville  ...       60540  Central  OFF-ST-10002743  Office Supplies
# 4  Philadelphia  ...       19143     East  OFF-AR-10003478  Office Supplies
#
#   Sub-Category                                       Product Name    Sales  \
# 0        Paper  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448
# 1      Binders         GBC Standard Plastic Binding Systems Combs    3.540
# 2       Labels                                          Avery 508   11.784
# 3      Storage                      SAFCO Boltless Steel Shelving  272.736
# 4          Art  Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536
#
#    Quantity  Discount   Profit
# 0         2       0.2   5.5512
# 1         2       0.8  -5.4870
# 2         3       0.2   4.2717
# 3         3       0.2 -64.7748
# 4         3       0.2   4.8840
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  object
#  3   Ship Date       10194 non-null  object
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  object
#  6   Customer Name   10194 non-null  object
#  7   Segment         10194 non-null  object
#  8   Country/Region  10194 non-null  object
#  9   City            10194 non-null  object
#  10  State/Province  10194 non-null  object
#  11  Postal Code     10194 non-null  object
#  12  Region          10194 non-null  object
#  13  Product ID      10194 non-null  object
#  14  Category        10194 non-null  object
#  15  Sub-Category    10194 non-null  object
#  16  Product Name    10194 non-null  object
#  17  Sales           10194 non-null  float64
#  18  Quantity        10194 non-null  int64
#  19  Discount        10194 non-null  float64
#  20  Profit          10194 non-null  float64
# dtypes: float64(3), int64(2), object(16)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#              Row ID         Sales      Quantity      Discount        Profit
# count  10194.000000  10194.000000  10194.000000  10194.000000  10194.000000
# mean    5097.500000    228.225854      3.791838      0.155385     28.673417
# std     2942.898656    619.906839      2.228317      0.206249    232.465115
# min        1.000000      0.444000      1.000000      0.000000  -6599.978000
# 25%     2549.250000     17.220000      2.000000      0.000000      1.760800
# 50%     5097.500000     53.910000      3.000000      0.200000      8.690000
# 75%     7645.750000    209.500000      5.000000      0.200000     29.297925
# max    10194.000000  22638.480000     14.000000      0.800000   8399.976000

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  datetime64[ns]
#  3   Ship Date       10194 non-null  datetime64[ns]
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  object
#  6   Customer Name   10194 non-null  object
#  7   Segment         10194 non-null  object
#  8   Country/Region  10194 non-null  object
#  9   City            10194 non-null  object
#  10  State/Province  10194 non-null  object
#  11  Postal Code     10194 non-null  object
#  12  Region          10194 non-null  object
#  13  Product ID      10194 non-null  object
#  14  Category        10194 non-null  object
#  15  Sub-Category    10194 non-null  object
#  16  Product Name    10194 non-null  object
#  17  Sales           10194 non-null  float64
#  18  Quantity        10194 non-null  int64
#  19  Discount        10194 non-null  float64
#  20  Profit          10194 non-null  float64
# dtypes: datetime64[ns](2), float64(3), int64(2), object(14)
# memory usage: 1.6+ MB

# %%
df['Delivery Days'] = (df['Ship Date'] - df['Order Date']).dt.days

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800 2023-03-01 2023-07-01  Standard Class    DP-13000
# 1       2  US-2023-112326 2023-04-01 2023-08-01  Standard Class    PO-19195
# 2       3  US-2023-112326 2023-04-01 2023-08-01  Standard Class    PO-19195
# 3       4  US-2023-112326 2023-04-01 2023-08-01  Standard Class    PO-19195
# 4       5  US-2023-141817 2023-05-01 2023-12-01  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City  ...   Region  \
# 0  Darren Powers     Consumer  United States       Houston  ...  Central
# 1  Phillina Ober  Home Office  United States    Naperville  ...  Central
# 2  Phillina Ober  Home Office  United States    Naperville  ...  Central
# 3  Phillina Ober  Home Office  United States    Naperville  ...  Central
# 4     Mick Brown     Consumer  United States  Philadelphia  ...     East
#
#         Product ID         Category Sub-Category  \
# 0  OFF-PA-10000174  Office Supplies        Paper
# 1  OFF-BI-10004094  Office Supplies      Binders
# 2  OFF-LA-10003223  Office Supplies       Labels
# 3  OFF-ST-10002743  Office Supplies      Storage
# 4  OFF-AR-10003478  Office Supplies          Art
#
#                                         Product Name    Sales Quantity  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448        2
# 1         GBC Standard Plastic Binding Systems Combs    3.540        2
# 2                                          Avery 508   11.784        3
# 3                      SAFCO Boltless Steel Shelving  272.736        3
# 4  Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536        3
#
#    Discount   Profit  Delivery Days
# 0       0.2   5.5512            122
# 1       0.8  -5.4870            122
# 2       0.2   4.2717            122
# 3       0.2 -64.7748            122
# 4       0.2   4.8840            214
#
# [5 rows x 22 columns]

# %%
df['Category'].unique()
# Out:
# array(['Office Supplies', 'Furniture', 'Technology'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country/Region    0
# City              0
# State/Province    0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Delivery Days     0
# dtype: int64

# %%
category_sales = (df.groupby('Category')['Sales'].sum())
category_sales
# Out:
# Category
# Furniture          754747.7613
# Office Supplies    731893.3140
# Technology         839893.2790
# Name: Sales, dtype: float64

# %%
category_sales.plot( kind='bar',figsize=(8,5))
plt.title("Sales by Category")
plt.ylabel("Total Sales")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Sales'],bins=30)
plt.title("Sales Distribution")
plt.show()

# %%
sns.barplot(
    data=df,
    x="Category",
    y="Profit"
)

plt.title("Profit by Category")
plt.show()

# %%
sns.barplot(
    data=df,
    x="Category",
    y="Sales"
)

plt.title("Sales Distribution by Category")
plt.show()

# %%
sns.boxplot(
    data=df,
    y="Profit"
)

plt.title("Profit Distribution")
plt.show()

# %%
sns.boxplot(
    data=df,
    x="Category",
    y="Profit"
)

plt.title("Profit Variation Across Categories")
plt.show()

# %%
df["Discount"].unique()
# Out:
# array([0.2 , 0.8 , 0.  , 0.6 , 0.15, 0.7 , 0.5 , 0.4 , 0.1 , 0.3 , 0.32,
#        0.45])

# %%
sns.scatterplot(
    data=df,
    x="Discount",
    y="Profit"
)

plt.title("Impact of Discount on Profit")
plt.show()

# %%
numeric_df = df.select_dtypes(
    include="number"
)

# %%
corr = numeric_df.corr()

corr
# Out:
#                  Row ID     Sales  Quantity  Discount    Profit  Delivery Days
# Row ID         1.000000 -0.008958  0.000502 -0.001474  0.003022       0.020314
# Sales         -0.008958  1.000000  0.198457 -0.027756  0.481460       0.006800
# Quantity       0.000502  0.198457  1.000000  0.007475  0.066145      -0.004462
# Discount      -0.001474 -0.027756  0.007475  1.000000 -0.218882       0.022105
# Profit         0.003022  0.481460  0.066145 -0.218882  1.000000       0.020492
# Delivery Days  0.020314  0.006800 -0.004462  0.022105  0.020492       1.000000

# %%
sns.heatmap(
    corr,
    annot=True
)

plt.title("Correlation Heatmap")
plt.show()

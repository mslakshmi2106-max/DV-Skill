# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_excel("/content/AAPL.xlsx")
df
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2014-09-29  100.589996  100.690002   98.040001   99.620003   93.514290
# 1   2014-10-06   99.949997  102.379997   98.309998  100.730003   94.556244
# 2   2014-10-13  101.330002  101.779999   95.180000   97.669998   91.683792
# 3   2014-10-20   98.320000  105.489998   98.220001  105.220001   98.771042
# 4   2014-10-27  104.849998  108.040001  104.699997  108.000000  101.380676
# ..         ...         ...         ...         ...         ...         ...
# 179 2018-03-05  175.210007  180.000000  174.270004  179.979996  179.979996
# 180 2018-03-12  180.289993  183.500000  177.619995  178.020004  178.020004
# 181 2018-03-19  177.320007  177.470001  164.940002  164.940002  164.940002
# 182 2018-03-26  168.070007  175.149994  165.190002  167.779999  167.779999
# 183 2018-03-29  167.804993  171.750000  166.899994  167.779999  167.779999
#
#         Volume
# 0    142718700
# 1    280258200
# 2    358539800
# ...

# %%
df.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2014-09-29  100.589996  100.690002   98.040001   99.620003   93.514290
# 1 2014-10-06   99.949997  102.379997   98.309998  100.730003   94.556244
# 2 2014-10-13  101.330002  101.779999   95.180000   97.669998   91.683792
# 3 2014-10-20   98.320000  105.489998   98.220001  105.220001   98.771042
# 4 2014-10-27  104.849998  108.040001  104.699997  108.000000  101.380676
#
#       Volume
# 0  142718700
# 1  280258200
# 2  358539800
# 3  358532900
# 4  220230600

# %%
df.tail()
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 179 2018-03-05  175.210007  180.000000  174.270004  179.979996  179.979996
# 180 2018-03-12  180.289993  183.500000  177.619995  178.020004  178.020004
# 181 2018-03-19  177.320007  177.470001  164.940002  164.940002  164.940002
# 182 2018-03-26  168.070007  175.149994  165.190002  167.779999  167.779999
# 183 2018-03-29  167.804993  171.750000  166.899994  167.779999  167.779999
#
#         Volume
# 179  139852700
# 180  155417500
# 181  172670700
# 182  157898400
# 183   38398505

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       184 non-null    datetime64[ns]
#  1   Open       184 non-null    float64
#  2   High       184 non-null    float64
#  3   Low        184 non-null    float64
#  4   Close      184 non-null    float64
#  5   Adj Close  184 non-null    float64
#  6   Volume     184 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 10.2 KB

# %%
print(df.isnull().sum())
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df = df.sort_values("Date")

# %%
df["Daily Price Change"] = df["Close"].diff()

# %%
df["Daily Percentage Change"] = df["Close"].pct_change() * 100

# %%
print(df.head(10))
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2014-09-29  100.589996  100.690002   98.040001   99.620003   93.514290
# 1 2014-10-06   99.949997  102.379997   98.309998  100.730003   94.556244
# 2 2014-10-13  101.330002  101.779999   95.180000   97.669998   91.683792
# 3 2014-10-20   98.320000  105.489998   98.220001  105.220001   98.771042
# 4 2014-10-27  104.849998  108.040001  104.699997  108.000000  101.380676
# 5 2014-11-03  108.220001  110.300003  107.720001  109.010002  102.328766
# 6 2014-11-10  109.019997  114.190002  108.400002  114.180000  107.646675
# 7 2014-11-17  114.269997  117.570000  113.300003  116.470001  109.805626
# 8 2014-11-24  116.849998  119.750000  116.620003  118.930000  112.124863
# 9 2014-12-01  118.809998  119.250000  111.269997  115.000000  108.419746
#
#       Volume  Daily Price Change  Daily Percentage Change
# 0  142718700                 NaN                      NaN
# ...

# %%
print("\nStock Price Analysis:")
print("Highest Price:", df["High"].max())
print("Lowest Price:", df["Low"].min())
print("Average Closing Price:", df["Close"].mean())
# Out:
# Stock Price Analysis:
# Highest Price: 183.5
# Lowest Price: 89.470001
# Average Closing Price: 127.35266294565217

# %%
print("\nDaily Price Change:")
print(df[["Date", "Close", "Daily Price Change", "Daily Percentage Change"]])
# Out:
# Daily Price Change:
#           Date       Close  Daily Price Change  Daily Percentage Change
# 0   2014-09-29   99.620003                 NaN                      NaN
# 1   2014-10-06  100.730003            1.110000                 1.114234
# 2   2014-10-13   97.669998           -3.060005                -3.037829
# 3   2014-10-20  105.220001            7.550003                 7.730115
# 4   2014-10-27  108.000000            2.779999                 2.642082
# ..         ...         ...                 ...                      ...
# 179 2018-03-05  179.979996            3.769989                 2.139486
# 180 2018-03-12  178.020004           -1.959992                -1.089005
# 181 2018-03-19  164.940002          -13.080002                -7.347490
# 182 2018-03-26  167.779999            2.839997                 1.721836
# 183 2018-03-29  167.779999            0.000000                 0.000000
#
# [184 rows x 4 columns]

# %%
df['Daily Percentage Return'] = df['Close'].pct_change() * 100
print('\nDaily Percentage Return:')
print(df[['Date', 'Close', 'Daily Percentage Return']].head())
# Out:
# Daily Percentage Return:
#         Date       Close  Daily Percentage Return
# 0 2014-09-29   99.620003                      NaN
# 1 2014-10-06  100.730003                 1.114234
# 2 2014-10-13   97.669998                -3.037829
# 3 2014-10-20  105.220001                 7.730115
# 4 2014-10-27  108.000000                 2.642082

# %%
biggest_losses = df.sort_values(by='Daily Percentage Return').head(5)
print(biggest_losses[['Date', 'Close', 'Daily Percentage Return']])
# Out:
#           Date       Close  Daily Percentage Return
# 82  2016-04-25   93.739998               -11.298261
# 46  2015-08-17  105.760002                -8.796134
# 66  2016-01-04   96.959999                -7.885239
# 181 2018-03-19  164.940002                -7.347490
# 58  2015-11-09  112.339996                -7.203042

# %%
biggest_gains = df.sort_values(by='Daily Percentage Return', ascending=False).head(5)
print(biggest_gains[['Date', 'Close', 'Daily Percentage Return']])
# Out:
#           Date       Close  Daily Percentage Return
# 102 2016-09-12  114.919998                11.432174
# 176 2018-02-12  172.429993                10.242305
# 3   2014-10-20  105.220001                 7.730115
# 55  2015-10-19  119.080002                 7.240635
# 47  2015-08-24  113.290001                 7.119893

# %%
average_volume = df['Volume'].mean()
minimum_volume = df['Volume'].min()
maximum_volume = df['Volume'].max()

print(f"Average Trading Volume: {average_volume:,.2f}")
print(f"Minimum Trading Volume: {minimum_volume:,.2f}")
print(f"Maximum Trading Volume: {maximum_volume:,.2f}")
# Out:
# Average Trading Volume: 191,016,776.11
# Minimum Trading Volume: 38,398,505.00
# Maximum Trading Volume: 500,363,000.00

# %%
df
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2014-09-29  100.589996  100.690002   98.040001   99.620003   93.514290
# 1   2014-10-06   99.949997  102.379997   98.309998  100.730003   94.556244
# 2   2014-10-13  101.330002  101.779999   95.180000   97.669998   91.683792
# 3   2014-10-20   98.320000  105.489998   98.220001  105.220001   98.771042
# 4   2014-10-27  104.849998  108.040001  104.699997  108.000000  101.380676
# ..         ...         ...         ...         ...         ...         ...
# 179 2018-03-05  175.210007  180.000000  174.270004  179.979996  179.979996
# 180 2018-03-12  180.289993  183.500000  177.619995  178.020004  178.020004
# 181 2018-03-19  177.320007  177.470001  164.940002  164.940002  164.940002
# 182 2018-03-26  168.070007  175.149994  165.190002  167.779999  167.779999
# 183 2018-03-29  167.804993  171.750000  166.899994  167.779999  167.779999
#
#         Volume  Daily Price Change  Daily Percentage Change
# ...

# %%
plt.figure(figsize=(10, 5))
plt.plot(df["Date"], df["Close"])
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.title("APPLE STOCK PRICE ANALYSIS")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
